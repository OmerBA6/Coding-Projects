# %%
df = pd.read_csv('salaries_by_college_major.csv')

# %%
import pandas as pd

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
clean_df = df.dropna() # Delete the (Non )

# %%
# Highest mid career Major
print(clean_df['Mid-Career Median Salary'].idxmax())
print(clean_df['Mid-Career Median Salary'][8])
clean_df['Undergraduate Major'][8]

# %%
# Lowest starting career earning major
print(clean_df['Starting Median Salary'].idxmin())
print(clean_df['Starting Median Salary'][49])
clean_df['Undergraduate Major'][49]

# %%
# Lowest risk mid-career salary major
spread_col = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
low_risk = clean_df.sort_values('Spread')
print(low_risk[['Undergraduate Major', 'Spread']].tail())
low_risk[['Undergraduate Major', 'Spread']].head()
# Out:
#    Undergraduate Major    Spread
# 42          Philosophy  132500.0
# 36           Marketing  132900.0
# 37                Math  137800.0
# 22             Finance  147800.0
# 17           Economics  159400.0
#            Undergraduate Major   Spread
# 40                     Nursing  50700.0
# 43         Physician Assistant  57600.0
# 41                   Nutrition  65300.0
# 49                     Spanish  65400.0
# 27  Health Care Administration  66400.0

# %%
# Highest potential mid career salary major
highest_potential = clean_df.sort_values('Mid-Career 90th Percentile Salary')
highest_potential[['Undergraduate Major', 'Mid-Career 90th Percentile Salary']].tail()
